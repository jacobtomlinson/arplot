# %%
import iris
from arplot import arplot

# %%
data = iris.load_cube("/Users/jtomlinson/Projects/informatics-lab/arplot/cafef7005477edb001aa7dc50eab78c5ef89d420.nc")
data
# Out:
# <iris 'Cube' of air_temperature / (K) (realization: 18; pressure: 33; latitude: 960; longitude: 1280)>

# %%
arplot.plot(data[0, 12, :, :])
# Out:
# <PIL.Image.Image image mode=RGB size=980x490 at 0x7FD3267D0B20>
